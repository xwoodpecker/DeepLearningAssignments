# %% [markdown]
# # Assignment 5

# %% [markdown]
# ## 5.1 Paraphase Detection with CNNs

# %% [markdown]
# Paraphrase detection in Natural Language Processing refers to the task of deciding whether two sentences are paraphrases of each other. For instance, the two sentences "Alice and her husband Bob are on vacation" and "Bob and his spouse Alice are on holidays" would be considered paraphrases of each other.
#
# In this exercise, we devise a CNN to perform the task of paraphase detection. Here are some key ideas for a possible approach:
# - make use of word embeddings (e.g., word2vec or GloVe)
# - truncate or pad the input sentences to have a fixed length (e.g., 25)
# - compute a similarity matrix based on the word embeddings: the entry in component (i,j) corresponds to the similarity between the i-th word from the first sentence and the j-th word from the second sentence
# - use this similarity matrix as an input for a CNN
# - the CNN consists of a sequence of convolutional/max-pooling layer groups
# - the last layer of the network consists of a single neuron with a sigmoid activation function, given that this is a binary classification problem

# %%
import numpy as np

# execute this code only once to download and extract the GloVe word embeddings
#!wget http://nlp.stanford.edu/data/glove.6B.zip
#!unzip -q glove.6B.zip

path_to_glove_file = "./glove.6B.100d.txt"

embeddings_index = {}
with open(path_to_glove_file) as f:
    for line in f:
        word, coefs = line.split(maxsplit=1)
        coefs = np.fromstring(coefs, "f", sep=" ")
        embeddings_index[word] = coefs

print("Found %s word vectors." % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %% [markdown]
# Given that the data consists of pairs of sentences that are paraphrases of each other, we first need to create our training and test data, so that also negative examples are included. To this end, we pair a sentence with another random sentence from the slice of the data considered -- the probability that the two are paraphrases should be close to zero. For the positive examples, we just use pairs as provided in the data. For each pair of sentences considered, we consider up to `sentence_len` words and compute a similarity matrix. Each component of the similarity matrix corresponds to the cosine similarity between two words from the two sentences. When we compute such a similarity matrix for a sentence with itself, we obtain a matrix with ones on the main diagonal.

# %%
import numpy as np
import string
import nltk
import pandas as pd
import random

# cosine similarity
def cosine(a,b):
    return np.dot(a,b)/(np.linalg.norm(a)*np.linalg.norm(b))

# number of sentence pairs to consider
num_pairs = 10000

# sentence length to consider
sentence_len = 10

# read in sentence-pair data
sentence_pairs = pd.read_csv('../data/pd-train.tsv', sep='\t+', header=None)

# determine sentence pairs for training
train_sentence_pairs = sentence_pairs[:num_pairs].copy(deep=True)

# determine sentence pairs for testing (20%)
test_sentence_pairs = sentence_pairs[num_pairs:int(1.2*num_pairs)].copy(deep=True)

def create_data(pairs):
    
    # convert to lower case
    pairs[0] = pairs[0].str.lower()
    pairs[1] = pairs[1].str.lower()

    # remove punctuation
    for c in string.punctuation:
        pairs[0] = pairs[0].str.replace(c, ' ')
        pairs[1] = pairs[1].str.replace(c, ' ')

    # tokenize sentences    
    pairs[2] = pairs[0].apply(lambda s : nltk.word_tokenize(s))
    pairs[3] = pairs[1].apply(lambda s : nltk.word_tokenize(s))

    # matrices for positive pairs
    positive_pairs = np.zeros((len(pairs), sentence_len, sentence_len))

    for i in range(0, len(pairs)):
        for j in range(0, min(sentence_len, len(pairs[2][pairs.index[i]]))):        
            first_word = pairs[2][pairs.index[i]][j]
            if first_word in embeddings_index.keys():
                for k in range(0, min(sentence_len, len(pairs[3][pairs.index[i]]))):        
                    second_word = pairs[3][pairs.index[i]][k]
                    if second_word in embeddings_index.keys():
                        positive_pairs[i][j][k] = cosine(embeddings_index[first_word], embeddings_index[second_word])

    # matrices for negative pairs
    negative_pairs = np.zeros((len(pairs), sentence_len, sentence_len))

    for i in range(0, len(pairs)):
        g = random.randrange(0, len(pairs))
        for j in range(0, min(sentence_len, len(pairs[2][pairs.index[i]]))):        
            first_word = pairs[2][pairs.index[i]][j]
            if first_word in embeddings_index.keys():
                for k in range(0, min(sentence_len, len(pairs[3][pairs.index[g]]))):        
                    second_word = pairs[3][pairs.index[g]][k]
                    if second_word in embeddings_index.keys():
                        negative_pairs[i][j][k] = cosine(embeddings_index[first_word], embeddings_index[second_word])                    

    # concatenate positive and negative pairs into data matrix
    X = np.concatenate((positive_pairs, negative_pairs), axis=0)

    # target vector: first half are positive pairs, second half are negative pairs
    y = np.ones((2*len(pairs),1))
    y[len(pairs):] = 0    
    
    return (X,y)

(X_train, y_train) = create_data(train_sentence_pairs)
(X_test, y_test) = create_data(test_sentence_pairs)
# Out:
# /var/folders/t0/vcm49tgj5nb4bn96ll0dtwnc0000gn/T/ipykernel_9232/1521137951.py:18: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   sentence_pairs = pd.read_csv('../data/pd-train.tsv', sep='\t+', header=None)
# /var/folders/t0/vcm49tgj5nb4bn96ll0dtwnc0000gn/T/ipykernel_9232/1521137951.py:32: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   pairs[0] = pairs[0].str.replace(c, ' ')
# /var/folders/t0/vcm49tgj5nb4bn96ll0dtwnc0000gn/T/ipykernel_9232/1521137951.py:33: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   pairs[1] = pairs[1].str.replace(c, ' ')
# /var/folders/t0/vcm49tgj5nb4bn96ll0dtwnc0000gn/T/ipykernel_9232/1521137951.py:32: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   pairs[0] = pairs[0].str.replace(c, ' ')
# /var/folders/t0/vcm49tgj5nb4bn96ll0dtwnc0000gn/T/ipykernel_9232/1521137951.py:33: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   pairs[1] = pairs[1].str.replace(c, ' ')

# %%
# turn off tensorflow info and warning messages
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 

import numpy as np
from keras import models
from keras import layers
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import Flatten

# describe model architecture
model = Sequential()
model.add(Conv2D(64, (3, 3), activation='relu', strides=(1,1), padding='same', input_shape=(sentence_len, sentence_len, 1)))
model.add(MaxPooling2D((2, 2), strides=(2,2)))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()

# compile model
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# train model
history = model.fit(X_train, y_train, batch_size=64, epochs=30, verbose=1, validation_split=0.2)

# evaluate model
model.evaluate(X_test, y_test)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 10, 10, 64)        640
#
#  max_pooling2d_8 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_6 (Flatten)         (None, 1600)              0
#
#  dense_14 (Dense)            (None, 512)               819712
#
#  dense_15 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 820,865
# Trainable params: 820,865
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 250/250 [==============================] - 3s 8ms/step - loss: 0.3443 - accuracy: 0.8453 - val_loss: 0.1387 - val_accuracy: 0.9708
# Epoch 2/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.1843 - accuracy: 0.9286 - val_loss: 0.6710 - val_accuracy: 0.7513
# Epoch 3/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.1499 - accuracy: 0.9419 - val_loss: 0.1959 - val_accuracy: 0.9405
# Epoch 4/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.1317 - accuracy: 0.9493 - val_loss: 0.0845 - val_accuracy: 0.9773
# Epoch 5/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.1198 - accuracy: 0.9541 - val_loss: 0.2047 - val_accuracy: 0.9353
# Epoch 6/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.1088 - accuracy: 0.9598 - val_loss: 0.1093 - val_accuracy: 0.9678
# Epoch 7/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.1012 - accuracy: 0.9623 - val_loss: 0.1726 - val_accuracy: 0.9480
# Epoch 8/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0981 - accuracy: 0.9621 - val_loss: 0.1529 - val_accuracy: 0.9595
# Epoch 9/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0928 - accuracy: 0.9653 - val_loss: 0.0944 - val_accuracy: 0.9735
# Epoch 10/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0858 - accuracy: 0.9687 - val_loss: 0.0558 - val_accuracy: 0.9873
# Epoch 11/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0859 - accuracy: 0.9683 - val_loss: 0.1957 - val_accuracy: 0.9415
# Epoch 12/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0794 - accuracy: 0.9698 - val_loss: 0.1245 - val_accuracy: 0.9633
# Epoch 13/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0761 - accuracy: 0.9716 - val_loss: 0.1891 - val_accuracy: 0.9503
# Epoch 14/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0719 - accuracy: 0.9756 - val_loss: 0.1724 - val_accuracy: 0.9530
# Epoch 15/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0690 - accuracy: 0.9748 - val_loss: 0.1662 - val_accuracy: 0.9548
# Epoch 16/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0703 - accuracy: 0.9738 - val_loss: 0.1214 - val_accuracy: 0.9663
# Epoch 17/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0628 - accuracy: 0.9766 - val_loss: 0.2326 - val_accuracy: 0.9373
# Epoch 18/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0596 - accuracy: 0.9786 - val_loss: 0.2391 - val_accuracy: 0.9390
# Epoch 19/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0571 - accuracy: 0.9794 - val_loss: 0.1109 - val_accuracy: 0.9728
# Epoch 20/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0567 - accuracy: 0.9793 - val_loss: 0.1444 - val_accuracy: 0.9680
# Epoch 21/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0533 - accuracy: 0.9812 - val_loss: 0.3569 - val_accuracy: 0.9110
# Epoch 22/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0501 - accuracy: 0.9811 - val_loss: 0.1348 - val_accuracy: 0.9688
# Epoch 23/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0477 - accuracy: 0.9828 - val_loss: 0.2069 - val_accuracy: 0.9520
# Epoch 24/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0452 - accuracy: 0.9829 - val_loss: 0.2098 - val_accuracy: 0.9498
# Epoch 25/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0440 - accuracy: 0.9841 - val_loss: 0.2556 - val_accuracy: 0.9388
# Epoch 26/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0415 - accuracy: 0.9853 - val_loss: 0.2048 - val_accuracy: 0.9595
# Epoch 27/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0410 - accuracy: 0.9854 - val_loss: 0.1122 - val_accuracy: 0.9778
# Epoch 28/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0357 - accuracy: 0.9866 - val_loss: 0.1533 - val_accuracy: 0.9720
# Epoch 29/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0353 - accuracy: 0.9866 - val_loss: 0.2758 - val_accuracy: 0.9383
# Epoch 30/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0381 - accuracy: 0.9870 - val_loss: 0.2106 - val_accuracy: 0.9590
# 125/125 [==============================] - 1s 4ms/step - loss: 0.1592 - accuracy: 0.9633
# [0.15919962525367737, 0.9632500410079956]

# %% [markdown]
# Our model achieves an accuracy of more than 95% on our test data. However, note that the way that we created negative examples makes the task relatively easy. It would be interesting to see, maybe as an additional exercise, how well a really simple model (e.g., only consisting of dense layers) performs. As another idea, one could make the task more challenging by creating tough negative examples, for instance, by permuting or swapping individual words from a sentence instead of using another random sentence.

# %% [markdown]
# ## 5.2 Hyperparameter Tuning for CNNs

# %% [markdown]
# For this exercise, we adapt the example code from the [Hyperas documentation](https://github.com/maxpumperla/hyperas) to work on the Fashion MNIST dataset. We consider the following choices for our model:
# - between 1 and 3 groups of convolutional and max-pooling layers
# - number of filters per convolutional layer in {16, 32, 64}
# - dropout layer with dropout probability of 0.5 after every group of layers
# - number of neurons in second-to-last dense layer in {256, 512, 1024}
#
# Note that this opens up a combinatorial space of more than 750 model architectures to explore. Hyperas tries to explore this space in a smart manner, and we instruct it to try out 50 of the possible model architectures.

# %%
# turn off tensorflow info and warning messages
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import numpy as np
from hyperopt import Trials, STATUS_OK, tpe
from keras.datasets import fashion_mnist
from keras.layers import Dense, Dropout, Activation, Conv2D, MaxPooling2D, Flatten
from keras.models import Sequential
from keras.utils import np_utils

from hyperas import optim
from hyperas.distributions import choice, uniform

def data():
    """
    Data providing function:

    This function is separated from create_model() so that hyperopt
    won't reload data for each evaluation run.
    """
    (x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
    x_train = x_train.reshape(60000, 28, 28, 1)
    x_test = x_test.reshape(10000, 28, 28 , 1)
    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')
    x_train /= 255
    x_test /= 255
    nb_classes = 10
    y_train = np_utils.to_categorical(y_train, nb_classes)
    y_test = np_utils.to_categorical(y_test, nb_classes)
    return x_train, y_train, x_test, y_test


def create_model(x_train, y_train, x_test, y_test):
    """
    Model providing function:

    Create Keras model with double curly brackets dropped-in as needed.
    Return value has to be a valid python dictionary with two customary keys:
        - loss: Specify a numeric evaluation metric to be minimized
        - status: Just use STATUS_OK and see hyperopt documentation if not feasible
    The last one is optional, though recommended, namely:
        - model: specify the model just created so that we can later use it again.
    """
    model = Sequential()
    
    # first group of layers
    model.add(Conv2D({{choice([16, 32, 64])}}, (5, 5), activation='relu', strides=(1,1), padding='same', input_shape=(28, 28, 1)))
    model.add(MaxPooling2D((2, 2), strides=(2,2)))    
    
    # dropout after first group of layers?
    if {{choice(['dropout1', 'nodropout1'])}} in {'dropout1'}:
        model.add(Dropout(0.5))

    # second group of layers
    if {{choice(['one', 'two', 'three'])}} in {'two', 'three'}:
        model.add(Conv2D({{choice([16, 32, 64])}}, (5, 5), activation='relu', strides=(1,1), padding='same'))
        model.add(MaxPooling2D((2, 2), strides=(2,2)))
        
        # dropout after second group of layers?
        if {{choice(['dropout2', 'nodropout2'])}} in {'dropout2'}:
            model.add(Dropout(0.5))
    
        # third group of layers?
        if {{choice(['two', 'three'])}} in {'three'}:    
            model.add(Conv2D({{choice([16, 32, 64])}}, (5, 5), activation='relu', strides=(1,1), padding='same'))
            model.add(MaxPooling2D((2, 2), strides=(2,2)))        
        
            # dropout after second group of layers?
            if {{choice(['dropout3', 'nodropout3'])}} in {'dropout3'}:
                model.add(Dropout(0.5))

    model.add(Flatten())
    model.add(Dense({{choice([256, 512, 1024])}}, activation='relu'))
    model.add(Dense(10, activation='softmax'))

    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],
                  optimizer='sgd')

    result = model.fit(x_train, y_train,
              batch_size=64,
              epochs=2,
              verbose=2,
              validation_split=0.2)
    #get the highest validation accuracy of the training epochs
    validation_acc = np.amax(result.history['val_accuracy']) 
    print('Best validation acc of epoch:', validation_acc)
    return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}


if __name__ == '__main__':
    best_run, best_model = optim.minimize(model=create_model,
                                          data=data,
                                          algo=tpe.suggest,
                                          notebook_name='2022-vl-dl-assignment5',
                                          max_evals=50,
                                          trials=Trials())
    X_train, Y_train, X_test, Y_test = data()
    print("Evaluation of best performing model:")
    print(best_model.evaluate(X_test, Y_test))
    print("Architecture of best performing model:")
    best_model.summary()
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     import os
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from keras.datasets import fashion_mnist
# except:
#     pass
#
# try:
#     from keras.layers import Dense, Dropout, Activation, Conv2D, MaxPooling2D, Flatten
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.utils import np_utils
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'Conv2D': hp.choice('Conv2D', [16, 32, 64]),
#         'Conv2D_1': hp.choice('Conv2D_1', ['dropout1', 'nodropout1']),
#         'Conv2D_2': hp.choice('Conv2D_2', ['one', 'two', 'three']),
#         'Conv2D_3': hp.choice('Conv2D_3', [16, 32, 64]),
#         'Conv2D_4': hp.choice('Conv2D_4', ['dropout2', 'nodropout2']),
#         'Conv2D_5': hp.choice('Conv2D_5', ['two', 'three']),
#         'Conv2D_6': hp.choice('Conv2D_6', [16, 32, 64]),
#         'Conv2D_7': hp.choice('Conv2D_7', ['dropout3', 'nodropout3']),
#         'Dense': hp.choice('Dense', [256, 512, 1024]),
#     }
#
# >>> Data
#   1:
#   2: """
#   3: Data providing function:
#   4:
#   5: This function is separated from create_model() so that hyperopt
#   6: won't reload data for each evaluation run.
#   7: """
#   8: (x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
#   9: x_train = x_train.reshape(60000, 28, 28, 1)
#  10: x_test = x_test.reshape(10000, 28, 28 , 1)
#  11: x_train = x_train.astype('float32')
#  12: x_test = x_test.astype('float32')
#  13: x_train /= 255
#  14: x_test /= 255
#  15: nb_classes = 10
#  16: y_train = np_utils.to_categorical(y_train, nb_classes)
#  17: y_test = np_utils.to_categorical(y_test, nb_classes)
#  18:
#  19:
#  20:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:     """
#    4:     Model providing function:
#    5:
#    6:     Create Keras model with double curly brackets dropped-in as needed.
#    7:     Return value has to be a valid python dictionary with two customary keys:
#    8:         - loss: Specify a numeric evaluation metric to be minimized
#    9:         - status: Just use STATUS_OK and see hyperopt documentation if not feasible
#   10:     The last one is optional, though recommended, namely:
#   11:         - model: specify the model just created so that we can later use it again.
#   12:     """
#   13:     model = Sequential()
#   14:
#   15:     # first group of layers
#   16:     model.add(Conv2D(space['Conv2D'], (5, 5), activation='relu', strides=(1,1), padding='same', input_shape=(28, 28, 1)))
#   17:     model.add(MaxPooling2D((2, 2), strides=(2,2)))
#   18:
#   19:     # dropout after first group of layers?
#   20:     if space['Conv2D_1'] in {'dropout1'}:
#   21:         model.add(Dropout(0.5))
#   22:
#   23:     # second group of layers
#   24:     if space['Conv2D_2'] in {'two', 'three'}:
#   25:         model.add(Conv2D(space['Conv2D_3'], (5, 5), activation='relu', strides=(1,1), padding='same'))
#   26:         model.add(MaxPooling2D((2, 2), strides=(2,2)))
#   27:
#   28:         # dropout after second group of layers?
#   29:         if space['Conv2D_4'] in {'dropout2'}:
#   30:             model.add(Dropout(0.5))
#   31:
#   32:         # third group of layers?
#   33:         if space['Conv2D_5'] in {'three'}:
#   34:             model.add(Conv2D(space['Conv2D_6'], (5, 5), activation='relu', strides=(1,1), padding='same'))
#   35:             model.add(MaxPooling2D((2, 2), strides=(2,2)))
#   36:
#   37:             # dropout after second group of layers?
#   38:             if space['Conv2D_7'] in {'dropout3'}:
#   39:                 model.add(Dropout(0.5))
#   40:
#   41:     model.add(Flatten())
#   42:     model.add(Dense(space['Dense'], activation='relu'))
#   43:     model.add(Dense(10, activation='softmax'))
#   44:
#   45:     model.compile(loss='categorical_crossentropy', metrics=['accuracy'],
#   46:                   optimizer='sgd')
#   47:
#   48:     result = model.fit(x_train, y_train,
#   49:               batch_size=64,
#   50:               epochs=2,
#   51:               verbose=2,
#   52:               validation_split=0.2)
#   53:     #get the highest validation accuracy of the training epochs
#   54:     validation_acc = np.amax(result.history['val_accuracy'])
#   55:     print('Best validation acc of epoch:', validation_acc)
#   56:     return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}
#   57:
#   0%|                                                                            | 0/50 [00:00<?, ?trial/s, best loss=?]Metal device set to: Apple M1 Max
# Epoch 1/2
#
# 750/750 - 11s - loss: 0.9629 - accuracy: 0.6678 - val_loss: 0.6257 - val_accuracy: 0.7745 - 11s/epoch - 15ms/step
#
# Epoch 2/2
#
# 750/750 - 11s - loss: 0.5781 - accuracy: 0.7885 - val_loss: 0.5281 - val_accuracy: 0.8119 - 11s/epoch - 15ms/step
#
# Best validation acc of epoch:
# 0.8119166493415833
# Epoch 1/2
#
# 750/750 - 12s - loss: 1.1284 - accuracy: 0.5928 - val_loss: 0.7332 - val_accuracy: 0.7304 - 12s/epoch - 15ms/step
#
# Epoch 2/2
#
# 750/750 - 11s - loss: 0.6891 - accuracy: 0.7476 - val_loss: 0.6135 - val_accuracy: 0.7727 - 11s/epoch - 15ms/step
#
# Best validation acc of epoch:
# 0.7726666331291199
# Epoch 1/2
#
# 750/750 - 9s - loss: 0.9999 - accuracy: 0.6394 - val_loss: 0.6672 - val_accuracy: 0.7523 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.6354 - accuracy: 0.7656 - val_loss: 0.6199 - val_accuracy: 0.7744 - 9s/epoch - 12ms/step
#
# Best validation acc of epoch:
# 0.7744166851043701
# Epoch 1/2
#
# 750/750 - 9s - loss: 1.3026 - accuracy: 0.5185 - val_loss: 0.8646 - val_accuracy: 0.6748 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.7882 - accuracy: 0.7066 - val_loss: 0.8179 - val_accuracy: 0.7169 - 9s/epoch - 12ms/step
#
# Best validation acc of epoch:
# 0.7169166803359985
# Epoch 1/2
#
# 750/750 - 12s - loss: 1.1406 - accuracy: 0.6157 - val_loss: 0.7210 - val_accuracy: 0.7217 - 12s/epoch - 16ms/step
#
# Epoch 2/2
#
# 750/750 - 13s - loss: 0.6152 - accuracy: 0.7741 - val_loss: 0.5619 - val_accuracy: 0.7953 - 13s/epoch - 17ms/step
#
# Best validation acc of epoch:
# 0.7953333258628845
# Epoch 1/2
#
# 750/750 - 9s - loss: 1.1341 - accuracy: 0.5879 - val_loss: 0.7597 - val_accuracy: 0.7167 - 9s/epoch - 11ms/step
#
# Epoch 2/2
#
# 750/750 - 8s - loss: 0.6555 - accuracy: 0.7644 - val_loss: 0.5719 - val_accuracy: 0.7953 - 8s/epoch - 10ms/step
#
# Best validation acc of epoch:
# 0.7953333258628845
# Epoch 1/2
#
# 750/750 - 9s - loss: 1.2056 - accuracy: 0.5689 - val_loss: 0.6702 - val_accuracy: 0.7537 - 9s/epoch - 11ms/step
#
# Epoch 2/2
#
# 750/750 - 8s - loss: 0.6485 - accuracy: 0.7616 - val_loss: 0.6250 - val_accuracy: 0.7597 - 8s/epoch - 11ms/step
#
# Best validation acc of epoch:
# 0.7596666812896729
# Epoch 1/2
#
# 750/750 - 9s - loss: 1.1585 - accuracy: 0.5769 - val_loss: 0.7406 - val_accuracy: 0.7363 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 8s - loss: 0.7073 - accuracy: 0.7426 - val_loss: 0.6720 - val_accuracy: 0.7442 - 8s/epoch - 11ms/step
#
# Best validation acc of epoch:
# 0.7442499995231628
# Epoch 1/2
#
# 750/750 - 9s - loss: 0.9725 - accuracy: 0.6674 - val_loss: 0.7041 - val_accuracy: 0.7295 - 9s/epoch - 11ms/step
#
# Epoch 2/2
#
# 750/750 - 8s - loss: 0.5942 - accuracy: 0.7843 - val_loss: 0.5320 - val_accuracy: 0.8094 - 8s/epoch - 11ms/step
#
# Best validation acc of epoch:
# 0.809416651725769
# Epoch 1/2
#
# 750/750 - 12s - loss: 1.1613 - accuracy: 0.5833 - val_loss: 0.6775 - val_accuracy: 0.7536 - 12s/epoch - 15ms/step
#
# Epoch 2/2
#
# 750/750 - 11s - loss: 0.6669 - accuracy: 0.7566 - val_loss: 0.5599 - val_accuracy: 0.7917 - 11s/epoch - 15ms/step
#
# Best validation acc of epoch:
# 0.7916666865348816
# Epoch 1/2
#
# 750/750 - 9s - loss: 1.1093 - accuracy: 0.5965 - val_loss: 0.7412 - val_accuracy: 0.7184 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.6881 - accuracy: 0.7488 - val_loss: 0.6333 - val_accuracy: 0.7758 - 9s/epoch - 12ms/step
#
# Best validation acc of epoch:
# 0.7758333086967468
# Epoch 1/2
#
# 750/750 - 12s - loss: 0.9691 - accuracy: 0.6621 - val_loss: 0.7072 - val_accuracy: 0.7112 - 12s/epoch - 16ms/step
#
# Epoch 2/2
#
# 750/750 - 12s - loss: 0.5800 - accuracy: 0.7883 - val_loss: 0.5141 - val_accuracy: 0.8156 - 12s/epoch - 15ms/step
#
# Best validation acc of epoch:
# 0.815583348274231
# Epoch 1/2
#
# 750/750 - 7s - loss: 0.8285 - accuracy: 0.7208 - val_loss: 0.5522 - val_accuracy: 0.8072 - 7s/epoch - 10ms/step
#
# Epoch 2/2
#
# 750/750 - 7s - loss: 0.5419 - accuracy: 0.8074 - val_loss: 0.4874 - val_accuracy: 0.8261 - 7s/epoch - 10ms/step
#
# Best validation acc of epoch:
# 0.8260833024978638
# Epoch 1/2
#
# 750/750 - 10s - loss: 1.3571 - accuracy: 0.5478 - val_loss: 0.7457 - val_accuracy: 0.7087 - 10s/epoch - 14ms/step
#
# Epoch 2/2
#
# 750/750 - 10s - loss: 0.6631 - accuracy: 0.7550 - val_loss: 0.6093 - val_accuracy: 0.7778 - 10s/epoch - 14ms/step
#
# Best validation acc of epoch:
# 0.7777500152587891
# Epoch 1/2
#
# 750/750 - 13s - loss: 1.2529 - accuracy: 0.5439 - val_loss: 0.7591 - val_accuracy: 0.7054 - 13s/epoch - 17ms/step
#
# Epoch 2/2
#
# 750/750 - 12s - loss: 0.6987 - accuracy: 0.7402 - val_loss: 0.6763 - val_accuracy: 0.7432 - 12s/epoch - 16ms/step
#
# Best validation acc of epoch:
# 0.7431666851043701
# Epoch 1/2
#
# 750/750 - 8s - loss: 0.9009 - accuracy: 0.6872 - val_loss: 0.6511 - val_accuracy: 0.7433 - 8s/epoch - 11ms/step
#
# Epoch 2/2
#
# 750/750 - 8s - loss: 0.5800 - accuracy: 0.7915 - val_loss: 0.4979 - val_accuracy: 0.8230 - 8s/epoch - 11ms/step
#
# Best validation acc of epoch:
# 0.8230000138282776
# Epoch 1/2
#
# 750/750 - 8s - loss: 0.8274 - accuracy: 0.7208 - val_loss: 0.5620 - val_accuracy: 0.8001 - 8s/epoch - 10ms/step
#
# Epoch 2/2
#
# 750/750 - 7s - loss: 0.5396 - accuracy: 0.8068 - val_loss: 0.5324 - val_accuracy: 0.7987 - 7s/epoch - 10ms/step
#
# Best validation acc of epoch:
# 0.800083339214325
# Epoch 1/2
#
# 750/750 - 10s - loss: 0.8330 - accuracy: 0.7211 - val_loss: 0.5770 - val_accuracy: 0.7849 - 10s/epoch - 13ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.5401 - accuracy: 0.8063 - val_loss: 0.5299 - val_accuracy: 0.8097 - 9s/epoch - 12ms/step
#
# Best validation acc of epoch:
# 0.809666633605957
# Epoch 1/2
#
# 750/750 - 13s - loss: 0.9683 - accuracy: 0.6610 - val_loss: 0.6278 - val_accuracy: 0.7627 - 13s/epoch - 17ms/step
#
# Epoch 2/2
#
# 750/750 - 12s - loss: 0.5816 - accuracy: 0.7882 - val_loss: 0.5275 - val_accuracy: 0.8064 - 12s/epoch - 16ms/step
#
# Best validation acc of epoch:
# 0.8064166307449341
# Epoch 1/2
#
# 750/750 - 10s - loss: 1.0034 - accuracy: 0.6585 - val_loss: 0.6226 - val_accuracy: 0.7710 - 10s/epoch - 13ms/step
#
# Epoch 2/2
#
# 750/750 - 10s - loss: 0.5731 - accuracy: 0.7908 - val_loss: 0.5255 - val_accuracy: 0.8130 - 10s/epoch - 13ms/step
#
# Best validation acc of epoch:
# 0.812999963760376
# Epoch 1/2
#
# 750/750 - 9s - loss: 0.9027 - accuracy: 0.6872 - val_loss: 0.5899 - val_accuracy: 0.7805 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.5781 - accuracy: 0.7913 - val_loss: 0.5263 - val_accuracy: 0.8148 - 9s/epoch - 11ms/step
#
# Best validation acc of epoch:
# 0.8148333430290222
# Epoch 1/2
#
# 750/750 - 9s - loss: 0.8996 - accuracy: 0.6886 - val_loss: 0.5874 - val_accuracy: 0.7903 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.5797 - accuracy: 0.7929 - val_loss: 0.5168 - val_accuracy: 0.8162 - 9s/epoch - 11ms/step
#
# Best validation acc of epoch:
# 0.8162499666213989
# Epoch 1/2
#
# 750/750 - 9s - loss: 0.8993 - accuracy: 0.6917 - val_loss: 0.5701 - val_accuracy: 0.7968 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.5768 - accuracy: 0.7937 - val_loss: 0.5028 - val_accuracy: 0.8197 - 9s/epoch - 11ms/step
#
# Best validation acc of epoch:
# 0.8196666836738586
# Epoch 1/2
#
# 750/750 - 9s - loss: 0.8862 - accuracy: 0.6950 - val_loss: 0.6077 - val_accuracy: 0.7845 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.5794 - accuracy: 0.7910 - val_loss: 0.5282 - val_accuracy: 0.8164 - 9s/epoch - 11ms/step
#
# Best validation acc of epoch:
# 0.8164166808128357
# Epoch 1/2
#
# 750/750 - 9s - loss: 0.9020 - accuracy: 0.6880 - val_loss: 0.5932 - val_accuracy: 0.7795 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.5775 - accuracy: 0.7917 - val_loss: 0.5485 - val_accuracy: 0.8036 - 9s/epoch - 12ms/step
#
# Best validation acc of epoch:
# 0.8035833239555359
# Epoch 1/2
#
# 750/750 - 9s - loss: 0.9043 - accuracy: 0.6865 - val_loss: 0.5715 - val_accuracy: 0.7983 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.5782 - accuracy: 0.7931 - val_loss: 0.5010 - val_accuracy: 0.8217 - 9s/epoch - 12ms/step
#
# Best validation acc of epoch:
# 0.8216666579246521
# Epoch 1/2
#
# 750/750 - 8s - loss: 0.8284 - accuracy: 0.7221 - val_loss: 0.5996 - val_accuracy: 0.7747 - 8s/epoch - 11ms/step
#
# Epoch 2/2
#
# 750/750 - 8s - loss: 0.5420 - accuracy: 0.8073 - val_loss: 0.5326 - val_accuracy: 0.8036 - 8s/epoch - 10ms/step
#
# Best validation acc of epoch:
# 0.8035833239555359
# Epoch 1/2
#
# 750/750 - 9s - loss: 0.8871 - accuracy: 0.6952 - val_loss: 0.6634 - val_accuracy: 0.7422 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.5794 - accuracy: 0.7909 - val_loss: 0.5525 - val_accuracy: 0.8018 - 9s/epoch - 12ms/step
#
# Best validation acc of epoch:
# 0.8018333315849304
# Epoch 1/2
#
# 750/750 - 8s - loss: 0.8254 - accuracy: 0.7222 - val_loss: 0.5787 - val_accuracy: 0.7916 - 8s/epoch - 11ms/step
#
# Epoch 2/2
#
# 750/750 - 8s - loss: 0.5410 - accuracy: 0.8056 - val_loss: 0.4966 - val_accuracy: 0.8221 - 8s/epoch - 11ms/step
#
# Best validation acc of epoch:
# 0.8220833539962769
# Epoch 1/2
#
# 750/750 - 9s - loss: 0.8892 - accuracy: 0.6955 - val_loss: 0.5983 - val_accuracy: 0.7829 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.5796 - accuracy: 0.7919 - val_loss: 0.5482 - val_accuracy: 0.7906 - 9s/epoch - 12ms/step
#
# Best validation acc of epoch:
# 0.7905833125114441
# Epoch 1/2
#
# 750/750 - 9s - loss: 0.8281 - accuracy: 0.7229 - val_loss: 0.5692 - val_accuracy: 0.7972 - 9s/epoch - 11ms/step
#
# Epoch 2/2
#
# 750/750 - 8s - loss: 0.5414 - accuracy: 0.8061 - val_loss: 0.5077 - val_accuracy: 0.8223 - 8s/epoch - 11ms/step
#
# Best validation acc of epoch:
# 0.8222500085830688
# Epoch 1/2
#
# 750/750 - 9s - loss: 0.8999 - accuracy: 0.6877 - val_loss: 0.5792 - val_accuracy: 0.7927 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.5815 - accuracy: 0.7927 - val_loss: 0.5110 - val_accuracy: 0.8140 - 9s/epoch - 12ms/step
#
# Best validation acc of epoch:
# 0.8140000104904175
# Epoch 1/2
#
# 750/750 - 9s - loss: 0.9045 - accuracy: 0.6862 - val_loss: 0.5997 - val_accuracy: 0.7763 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.5792 - accuracy: 0.7915 - val_loss: 0.5085 - val_accuracy: 0.8207 - 9s/epoch - 12ms/step
#
# Best validation acc of epoch:
# 0.8207499980926514
# Epoch 1/2
#
# 750/750 - 8s - loss: 0.8292 - accuracy: 0.7239 - val_loss: 0.5752 - val_accuracy: 0.7916 - 8s/epoch - 11ms/step
#
# Epoch 2/2
#
# 750/750 - 8s - loss: 0.5417 - accuracy: 0.8058 - val_loss: 0.4997 - val_accuracy: 0.8192 - 8s/epoch - 11ms/step
#
# Best validation acc of epoch:
# 0.8192499876022339
# Epoch 1/2
#
# 750/750 - 9s - loss: 0.8867 - accuracy: 0.6945 - val_loss: 0.6295 - val_accuracy: 0.7565 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.5804 - accuracy: 0.7897 - val_loss: 0.5185 - val_accuracy: 0.8119 - 9s/epoch - 12ms/step
#
# Best validation acc of epoch:
# 0.8119166493415833
# Epoch 1/2
#
# 750/750 - 8s - loss: 0.8290 - accuracy: 0.7226 - val_loss: 0.5927 - val_accuracy: 0.7887 - 8s/epoch - 11ms/step
#
# Epoch 2/2
#
# 750/750 - 8s - loss: 0.5389 - accuracy: 0.8077 - val_loss: 0.4931 - val_accuracy: 0.8261 - 8s/epoch - 11ms/step
#
# Best validation acc of epoch:
# 0.8260833024978638
# Epoch 1/2
#
# 750/750 - 8s - loss: 0.8446 - accuracy: 0.7185 - val_loss: 0.5862 - val_accuracy: 0.7944 - 8s/epoch - 11ms/step
#
# Epoch 2/2
#
# 750/750 - 8s - loss: 0.5431 - accuracy: 0.8061 - val_loss: 0.4947 - val_accuracy: 0.8290 - 8s/epoch - 10ms/step
#
# Best validation acc of epoch:
# 0.8289999961853027
# Epoch 1/2
#
# 750/750 - 10s - loss: 1.1781 - accuracy: 0.5788 - val_loss: 0.7199 - val_accuracy: 0.7178 - 10s/epoch - 13ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.6550 - accuracy: 0.7604 - val_loss: 0.6038 - val_accuracy: 0.7724 - 9s/epoch - 12ms/step
#
# Best validation acc of epoch:
# 0.7724166512489319
# Epoch 1/2
#
# 750/750 - 12s - loss: 1.4115 - accuracy: 0.5004 - val_loss: 0.7533 - val_accuracy: 0.7357 - 12s/epoch - 16ms/step
#
# Epoch 2/2
#
# 750/750 - 12s - loss: 0.7244 - accuracy: 0.7299 - val_loss: 0.6354 - val_accuracy: 0.7676 - 12s/epoch - 16ms/step
#
# Best validation acc of epoch:
# 0.7675833106040955
# Epoch 1/2
#
# 750/750 - 8s - loss: 0.8611 - accuracy: 0.7086 - val_loss: 0.5643 - val_accuracy: 0.7993 - 8s/epoch - 10ms/step
#
# Epoch 2/2
#
# 750/750 - 7s - loss: 0.5460 - accuracy: 0.8044 - val_loss: 0.5426 - val_accuracy: 0.8058 - 7s/epoch - 10ms/step
#
# Best validation acc of epoch:
# 0.8057500123977661
# Epoch 1/2
#
# 750/750 - 9s - loss: 1.1559 - accuracy: 0.5837 - val_loss: 0.6655 - val_accuracy: 0.7543 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 8s - loss: 0.6446 - accuracy: 0.7633 - val_loss: 0.5538 - val_accuracy: 0.7953 - 8s/epoch - 11ms/step
#
# Best validation acc of epoch:
# 0.7953333258628845
# Epoch 1/2
#
# 750/750 - 10s - loss: 1.3195 - accuracy: 0.5117 - val_loss: 0.7671 - val_accuracy: 0.7094 - 10s/epoch - 13ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.7405 - accuracy: 0.7264 - val_loss: 0.6608 - val_accuracy: 0.7532 - 9s/epoch - 13ms/step
#
# Best validation acc of epoch:
# 0.753166675567627
# Epoch 1/2
#
# 750/750 - 11s - loss: 0.8370 - accuracy: 0.7228 - val_loss: 0.5751 - val_accuracy: 0.7964 - 11s/epoch - 14ms/step
#
# Epoch 2/2
#
# 750/750 - 10s - loss: 0.5418 - accuracy: 0.8064 - val_loss: 0.4980 - val_accuracy: 0.8230 - 10s/epoch - 14ms/step
#
# Best validation acc of epoch:
# 0.8230000138282776
# Epoch 1/2
#
# 750/750 - 10s - loss: 1.6030 - accuracy: 0.3995 - val_loss: 0.8962 - val_accuracy: 0.6547 - 10s/epoch - 13ms/step
#
# Epoch 2/2
#
# 750/750 - 10s - loss: 0.8091 - accuracy: 0.6996 - val_loss: 0.7237 - val_accuracy: 0.7436 - 10s/epoch - 13ms/step
#
# Best validation acc of epoch:
# 0.7435833215713501
# Epoch 1/2
#
# 750/750 - 9s - loss: 0.8172 - accuracy: 0.7261 - val_loss: 0.5744 - val_accuracy: 0.7905 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.5357 - accuracy: 0.8078 - val_loss: 0.4915 - val_accuracy: 0.8287 - 9s/epoch - 12ms/step
#
# Best validation acc of epoch:
# 0.8286666870117188
# Epoch 1/2
#
# 750/750 - 11s - loss: 1.1703 - accuracy: 0.5873 - val_loss: 0.6360 - val_accuracy: 0.7556 - 11s/epoch - 14ms/step
#
# Epoch 2/2
#
# 750/750 - 11s - loss: 0.6305 - accuracy: 0.7697 - val_loss: 0.5732 - val_accuracy: 0.7883 - 11s/epoch - 14ms/step
#
# Best validation acc of epoch:
# 0.7883332967758179
# Epoch 1/2
#
# 750/750 - 10s - loss: 1.1283 - accuracy: 0.5958 - val_loss: 0.6566 - val_accuracy: 0.7653 - 10s/epoch - 13ms/step
#
# Epoch 2/2
#
# 750/750 - 10s - loss: 0.6544 - accuracy: 0.7627 - val_loss: 0.5554 - val_accuracy: 0.7984 - 10s/epoch - 13ms/step
#
# Best validation acc of epoch:
# 0.7984166741371155
# Epoch 1/2
#
# 750/750 - 9s - loss: 0.8267 - accuracy: 0.7224 - val_loss: 0.6394 - val_accuracy: 0.7697 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 8s - loss: 0.5327 - accuracy: 0.8084 - val_loss: 0.5255 - val_accuracy: 0.8116 - 8s/epoch - 11ms/step
#
# Best validation acc of epoch:
# 0.8115833401679993
# Epoch 1/2
#
# 750/750 - 9s - loss: 0.8143 - accuracy: 0.7286 - val_loss: 0.5645 - val_accuracy: 0.8054 - 9s/epoch - 12ms/step
#
# Epoch 2/2
#
# 750/750 - 9s - loss: 0.5387 - accuracy: 0.8068 - val_loss: 0.4872 - val_accuracy: 0.8263 - 9s/epoch - 12ms/step
#
# Best validation acc of epoch:
# 0.8263333439826965
# Epoch 1/2
#
# 750/750 - 11s - loss: 1.1721 - accuracy: 0.5917 - val_loss: 0.6296 - val_accuracy: 0.7647 - 11s/epoch - 15ms/step
#
# Epoch 2/2
#
# 750/750 - 11s - loss: 0.6297 - accuracy: 0.7711 - val_loss: 0.5409 - val_accuracy: 0.7969 - 11s/epoch - 15ms/step
#
# Best validation acc of epoch:
# 0.796916663646698
# 100%|████████████████████████████████████████████████| 50/50 [15:40<00:00, 18.81s/trial, best loss: -0.8289999961853027]
# Evaluation of best performing model:
# 313/313 [==============================] - 3s 8ms/step - loss: 0.5126 - accuracy: 0.8211
# [0.5126142501831055, 0.8211000561714172]
# Architecture of best performing model:
# Model: "sequential_36"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_56 (Conv2D)          (None, 28, 28, 32)        832
#
#  max_pooling2d_56 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  flatten_36 (Flatten)        (None, 6272)              0
#
#  dense_72 (Dense)            (None, 256)               1605888
#
#  dense_73 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 1,609,290
# Trainable params: 1,609,290
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 5.3 Biases in CNNs

# %% [markdown]
# In this exercise, we look into a relatively recent paper from ICLR, namely:
# - **R. Geirhos, P. Rubisch, C. Michaelis, M. Bethge, F. A. Wichmann, W. Brendel**: *ImageNet- trained CNNs are biased towards texture; increasing shape bias improves accuracy and robustness*, ICLR 2019
#
# **(a) What is texture bias? Define it in your own words**
#
# CNNs are commonly believed to learn more and more complex representations of objects by piecing together shape information. However, as the paper demonstrates, this is not the case for several well-known architectures when trained on ImageNet. When images are modified in one of several ways (e.g., only retaining the outline of the image or replacing the texture of the image), all architectures perform quite poorly. This hints at CNNs relying mostly on texture information to classify objects. Humans, in contrast, perform substantially better, even when only presented with shape information.
#
# **(b) What are the tasks that the authors give to humans and CNNs in their experiments**
#
# Human study participants and the different CNNs are presented with modified versions of the images to see how much they depend on different aspects of the images (e.g., shape vs. texture). In the so-called cue-conflict experiments, humans are explicitly told to rely on either the shape or the texture of the image presented. It becomes clear that humans rely heavily on shape information whereas the CNNs considered rely mostly on texture information.
#
# **(c) How do the authors propose to overcome the texture bias in CNNs?**
#
# The authors construct a modified version of the ImageNet dataset named Stylized Image Net. The dataset swaps out the texture of the original image by using artistic images as new textures. The authors use different combinations of the original ImageNet and their novel dataset for training, testing, or retraining. It is shown that a CNN (ResNet) trained on Stylized ImageNet and fine-tuned on ImageNet can outperform the original ResNet trained only on ImageNet. Beyond that, the authors also show that the network trained on both datasets (i) works better on another dataset (Pascal VOC), which was not used for training and (ii) is more robust to different kinds of perturbations of the images.
